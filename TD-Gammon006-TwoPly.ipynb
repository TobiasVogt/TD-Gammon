# %% [markdown]
# # TwoPly
#
# Eine Möglichkeit bessere Entscheidungen zu Treffen ist sich die Reaktionen des Gegners vorzustellen und entsprechende Vorkehrungen zu treffen, oder einen zunächst nicht so guten Zug zieht, den man aber im eigenen Zug darauf sehr gut verwerten kann.
#
# ## TwoPlyPlayer
#
# Ein Spieler der eine Funktion bzw. ein Modell bekommt und dann den Gegnerzug noch miteinbezieht.
#
# Der TwoPlyPlayer bewertet den Zug folgendermaßen:
# 1. Er führt in aus
# 2. Zieht er für alle möglichen Gegnerwürfe alle möglichen Züge
# 3. Nimmt von jedem Wurf den geringsten Wert mit der Wahrscheinlichkeit des Wurfes multipliziert (1/36 bei Pasch, 1/18 sonst)
# 4. Maximiert den Wert aus 3.

# %%
from Player import ValuePlayer, ModelPlayer

class TwoPlyValuePlayer(ValuePlayer):
    
    def get_action(self, actions, game):
        # Spielstatus speichern
        old_state = game.get_state()
        # Variablen initialisieren
        best_value = float("-inf")
        best_action = None
        # Alle Züge durchsuchen
        for a in actions:
            # Zug ausführen
            game.execute_moves(a, self.player)
            # Spielstatus bewerten
            value = self.two_ply(game, self.player)
            # Besten merken
            if value > best_value:
                best_value = value
                best_action = a
            # Spiel zurücksetzen
            game.reset_to_state(old_state)
        return best_action
        
    def two_ply(self, game, player):
        # Alle möglichen Gegnerwürfe und dazugehörige Züge bewerten und mit der WS des Wurfes multiplizieren
        all_rolls = [(a,b) for a in range(1,7) for b in range(a,7)]
        value = 0
        for roll in all_rolls:
            probability = 1/18 if roll[0] != roll[1] else 1/36
            state = game.get_state()
            # Wir betrachten die Gegnerzüge
            moves = game.get_moves(roll, game.get_opponent(player))
            min_val = 1
            for move in moves:
                game.execute_moves(move, game.get_opponent(player))
                # Bewertet wird aber aus unserer Perspektive
                v = self.value(game, player)
                if v < min_val:
                    min_val = v
                game.reset_to_state(state)
            value += probability * min_val
        # Wert zurückgeben
        return value

    def get_name(self):
        return "TwoPlyValuePlayer [" + self.value.__name__ + "]"

class TwoPlyModelPlayer(TwoPlyValuePlayer):

    def __init__(self, player, model):
        TwoPlyValuePlayer.__init__(self, player, self.get_value)
        self.model = model
        
    def get_value(self, game, player):
        features = game.extractFeatures(player)
        v = self.model.get_output(features)
        v = 1 - v if self.player == game.players[0] else v
        return v
    
    def get_name(self):
        return "TwoPlyModelPlayer [" + self.model.get_name() +"]"

# %%
import time
import tensorflow as tf
from FasterBackgammon import Game
from NeuralNetModel import TDGammonModel

graph = tf.Graph()
sess = tf.Session(graph=graph)
with sess.as_default(), graph.as_default():
    model = TDGammonModel(sess, restore=True)
    start = time.time()
    model.test(games = 100, enemyPlayer = TwoPlyModelPlayer(Game.PLAYERS[1], model))
    print(time.time() - start, "Sekunden")
# Out:
# Restoring checkpoint: checkpoints/TD-Gammon/checkpoint.ckpt-1593683
# INFO:tensorflow:Restoring parameters from checkpoints/TD-Gammon/checkpoint.ckpt-1593683
# [Game 0] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 0:1 of 1 games (0.00%)
# [Game 1] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 0:2 of 2 games (0.00%)
# [Game 2] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 1:2 of 3 games (33.33%)
# [Game 3] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 1:3 of 4 games (25.00%)
# [Game 4] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 2:3 of 5 games (40.00%)
# [Game 5] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 2:4 of 6 games (33.33%)
# [Game 6] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 3:4 of 7 games (42.86%)
# [Game 7] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 4:4 of 8 games (50.00%)
# [Game 8] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white)
ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 23:55 of 78 games (29.49%)
# [Game 78] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 23:56 of 79 games (29.11%)
# [Game 79] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 23:57 of 80 games (28.75%)
# [Game 80] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 23:58 of 81 games (28.40%)
# [Game 81] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 23:59 of 82 games (28.05%)
# [Game 82] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 23:60 of 83 games (27.71%)
# [Game 83] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 23:61 of 84 games (27.38%)
# [Game 84] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 24:61 of 85 games (28.24%)
# [Game 85] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 24:62 of 86 games (27.91%)
# [Game 86] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 24:63 of 87 games (27.59%)
# [Game 87] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 25:63 of 88 games (28.41%)
# [Game 88] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 25:64 of 89 games (28.09%)
# [Game 89] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 26:64 of 90 games (28.89%)
# [Game 90] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 26:65 of 91 games (28.57%)
# [Game 91] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 26:66 of 92 games (28.26%)
# [Game 92] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 27:66 of 93 games (29.03%)
# [Game 93] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 27:67 of 94 games (28.72%)
# [Game 94] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 27:68 of 95 games (28.42%)
# [Game 95] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 28:68 of 96 games (29.17%)
# [Game 96] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 29:68 of 97 games (29.90%)
# [Game 97] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 29:69 of 98 games (29.59%)
# [Game 98] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 29:70 of 99 games (29.29%)
# [Game 99] ModelPlayer [TD-Gammon] (black) vs TwoPlyModelPlayer [TD-Gammon] (white) 29:71 of 100 games (29.00%)
# 8004.9661202430725 Sekunden

# %% [markdown]
# Der 2-ply Spieler ist __deutlich__ besser als der 1-ply Spieler! <br>
# Dafür ist die Geschwindigkeit enorm gesunken...
#
# ### Andere Spieler
#
# Die Leistung von TD-Gammon konnte sehr verbessert werden, aber funktioniert das auch mit den einfacheren Spielern?
#
# #### Singleton

# %%
import Player
import PlayerTest
from FasterBackgammon import Game

players = [TwoPlyValuePlayer(Game.PLAYERS[0], Player.singleton), ValuePlayer(Game.PLAYERS[1], Player.singleton)]

PlayerTest.test(players, 100)
# Out:
# Spiel 0 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 1 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 2 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 3 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 4 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 5 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 6 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 7 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 8 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 9 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 10 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 11 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 12 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 13 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 14 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 15 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 16 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 17 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 18 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 19 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 20 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 21 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 22 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 23 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 24 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 25 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 26 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 27 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 28 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 29 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 30 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 31 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 32 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 33 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 34 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 35 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 36 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 37 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 38 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 39 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 40 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 41 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 42 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 43 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 44 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 45 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 46 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 47 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 48 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 49 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 50 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 51 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 52 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 53 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 54 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 55 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 56 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 57 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 58 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 59 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 60 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 61 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 62 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 63 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 64 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 65 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 66 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 67 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 68 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 69 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 70 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 71 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 72 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 73 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 74 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 75 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 76 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 77 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 78 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 79 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 80 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 81 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 82 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 83 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 84 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 85 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 86 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 87 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 88 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 89 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 90 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 91 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 92 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 93 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 94 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 95 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 96 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 97 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 98 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 99 von 100 geht an ValuePlayer [singleton] ( white )
#
# {'white': 56, 'black': 44}
# 100 Spiele in  523.8134219646454 Sekunden

# %% [markdown]
# Keine Verbesserung für Singleton, eher noch eine Verschlechterung bei schlechterer Performance.
#
# Das kann dadruch passieren, dass es keinen Unterschied für singleton macht, ob die Gegnerzüge betrachtet werden oder nicht, weil Singleton nur auf die eigenen Steine schaut, die er in seinem eigenen Zug bereits nicht alleine stehen lässt, so dass der Gegner nichts an den Türmen von Singleton ändern kann.
#
# #### Way to go
#
# Bei way to go muss man noch beachten, dass dort nur die Gegnerschritte gezählt werden, wir den Wert von den gegnerischen Spielzügen jedoch aus der eigenen Perspektive bewerten. Nun ist es aber egal welcher Zug der Gegner ausführt, seine Schritte werden sich immer um den gleichen Betrag verringern. <br> <br>
# Daher müssen wir um way to go 2-ply fähig zu machen es so abändern, dass nur die eigenen Schritte gezählt werden, die - unter Umständen - von dem Gegner beeinflusst werden können, indem er den way to go Spieler raus wirft.

# %%
def way_to_go2(game, player):
    # Seite ermitteln
    black = player == game.players[0]
    # Steine besorgen
    own_checkers = game.white_checkers if not black else game.black_checkers
    # Schritte berechnen
    steps = 0
    # Steine auf dem Spielfeld
    for tower in own_checkers:
        if black:
            steps += (24 - tower) * game.points[tower]
        else:
            steps += tower * game.points[tower] * -1
    # Steine auf der Bar
    bar_chk = game.white_taken if not black else game.black_taken
    steps += 25 * bar_chk 
    return steps / 375

# %%
players = [TwoPlyValuePlayer(Game.PLAYERS[0], way_to_go2), ValuePlayer(Game.PLAYERS[1], Player.way_to_go)]

PlayerTest.test(players, 100)
# Out:
# Spiel 0 von 100 geht an ValuePlayer [way_to_go] ( white )
# Spiel 1 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 2 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 3 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 4 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 5 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 6 von 100 geht an ValuePlayer [way_to_go] ( white )
# Spiel 7 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 8 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 9 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 10 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 11 von 100 geht an ValuePlayer [way_to_go] ( white )
# Spiel 12 von 100 geht an ValuePlayer [way_to_go] ( white )
# Spiel 13 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 14 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 15 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 16 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 17 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 18 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 19 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 20 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 21 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 22 von 100 geht an ValuePlayer [way_to_go] ( white )
# Spiel 23 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 24 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 25 von 100 geht an ValuePlayer [way_to_go] ( white )
# Spiel 26 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 27 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 28 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 29 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 30 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 31 von 100 geht an ValuePlayer [way_to_go] ( white )
# Spiel 32 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 33 von 100 geht an ValuePlayer [way_to_go] ( white )
# Spiel 34 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 35 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 36 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 37 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 38 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 39 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 40 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 41 von 100 geht an ValuePlayer [way_to_go] ( white )
# Spiel 42 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 43 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 44 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 45 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 46 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 47 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e5fc0c61f710> in <module>()
#       1 players = [TwoPlyValuePlayer(Game.PLAYERS[0], way_to_go2), ValuePlayer(Game.PLAYERS[1], Player.way_to_go)]
#       2
# ----> 3 PlayerTest.test(players, 100)
#
# ~\Desktop\Uni\Machine Learning\TD-Gammon-Implementation\PlayerTest.py in test(players, games, debug)
#      10     for i in range(games):
#      11         game = Game()
# ---> 12         winner = game.play(players, debug=debug)
#      13         wins[winner] += 1
#      14         win_num = 0 if winner == game.players[0] else 1
#
# ~\Desktop\Uni\Machine Learning\TD-Gammon-Implementation\FasterBackgammon.py in play(self, player, debug)
#      90         while not self.get_winner():
#      91             #Zug ausführen
# ---> 92             self.next_step(player[player_num], player_num, debug=debug)
#      93             #Der andere Spieler ist dran
#      94             player_num = (player_num + 1) % 2
#
# ~\Desktop\Uni\Machine Learning\TD-Gammon-Implementation\FasterBackgammon.py in next_step(self, player, player_num, debug)
#     119         moves = self.get_moves(roll, self.players[player_num])
#     120         #Spieler fragen welche der Züge er gerne ausführen möchte
# --> 121         move = player.get_action(moves, self) if moves else None
#     122         #Zug ausführen falls es möglich ist
#     123         if move:
#
# <ipython-input-1-b9186cfa2902> in get_action(self, actions, game)
#      14             game.execute_moves(a, self.player)
#      15             # Spielstatus bewerten
# ---> 16             value = self.two_ply(game, self.player)
#      17             # Besten merken
#      18             if value > best_value:
#
# <ipython-input-1-b9186cfa2902> in two_ply(self, game, player)
#      39                 if v < min_val:
#      40                     min_val = v
# ---> 41                 game.reset_to_state(state)
#      42             value += probability * min_val
#      43         # Wert zurückgeben
#
# ~\Desktop\Uni\Machine Learning\TD-Gammon-Implementation\FasterBackgammon.py in reset_to_state(self, state)
#     173         self.white_taken = state[2]
#     174         #Positionen der schwarzen und weißen Steine aktualisieren
# --> 175         self.refresh_piece_positions()
#     176
#     177     #Aktualisiert die Listen mit den Position der Steine
#
# ~\Desktop\Uni\Machine Learning\TD-Gammon-Implementation\FasterBackgammon.py in refresh_piece_positions(self)
#     180         self.black_checkers = [i for i in range(24) if self.points[i] > 0]
#     181         #Positionen der weißen Steine
# --> 182         self.white_checkers = sorted([i for i in range(24) if self.points[i] < 0], reverse=True)
#     183
#     184     def get_moves(self, roll, player):
#
# ~\Desktop\Uni\Machine Learning\TD-Gammon-Implementation\FasterBackgammon.py in <listcomp>(.0)
#     180         self.black_checkers = [i for i in range(24) if self.points[i] > 0]
#     181         #Positionen der weißen Steine
# --> 182         self.white_checkers = sorted([i for i in range(24) if self.points[i] < 0], reverse=True)
#     183
#     184     def get_moves(self, roll, player):
#
# KeyboardInterrupt:

# %% [markdown]
# Nach 8 Stunden 47 nur 47 Spiele, dafür aber mit außerodentlichem Erfolg.

# %%
import Player
import PlayerTest
from FasterBackgammon import Game

players = [TwoPlyValuePlayer(Game.PLAYERS[0], way_to_go2), ValuePlayer(Game.PLAYERS[1], Player.singleton)]

PlayerTest.test(players, 100)
# Out:
# Spiel 0 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 1 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 2 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 3 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 4 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 5 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 6 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 7 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 8 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 9 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 10 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 11 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 12 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 13 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 14 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 15 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 16 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 17 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 18 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 19 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 20 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 21 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 22 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 23 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 24 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 25 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 26 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 27 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 28 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 29 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 30 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 31 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 32 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 33 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 34 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 35 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 36 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 37 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 38 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 39 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 40 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 41 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 42 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 43 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 44 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 45 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 46 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 47 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 48 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 49 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 50 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 51 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 52 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 53 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 54 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 55 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 56 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 57 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 58 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 59 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 60 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 61 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 62 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 63 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 64 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 65 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 66 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 67 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 68 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 69 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 70 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 71 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 72 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 73 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 74 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 75 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 76 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 77 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 78 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 79 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 80 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 81 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 82 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 83 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 84 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 85 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 86 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 87 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 88 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 89 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 90 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 91 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 92 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 93 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 94 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 95 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 96 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 97 von 100 geht an ValuePlayer [singleton] ( white )
# Spiel 98 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
# Spiel 99 von 100 geht an TwoPlyValuePlayer [way_to_go2] ( black )
#
# {'white': 52, 'black': 48}
# 100 Spiele in  722.6659970283508 Sekunden

# %% [markdown]
# #### 2-ply Blocker vs Singleton
# Blocker und Singleton mit 1-ply haben fast identisch gespielt, wie sieht das in 2-ply aus?

# %%
from FasterBackgammon import Game
import Player
import PlayerTest

players = [TwoPlyValuePlayer(Game.PLAYERS[0], Player.singleton), TwoPlyValuePlayer(Game.PLAYERS[1], Player.blocker)]

PlayerTest.test(players, 100)
# Out:
# Spiel 0 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 1 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 2 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 3 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 4 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 5 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 6 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 7 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 8 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 9 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 10 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 11 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 12 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 13 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 14 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 15 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 16 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 17 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 18 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 19 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 20 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 21 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 22 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 23 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 24 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 25 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 26 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 27 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 28 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 29 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 30 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 31 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 32 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 33 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 34 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 35 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 36 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 37 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 38 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 39 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 40 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 41 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 42 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 43 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 44 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 45 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 46 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 47 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 48 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 49 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 50 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 51 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 52 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 53 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 54 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 55 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 56 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 57 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 58 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 59 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 60 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 61 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 62 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 63 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 64 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 65 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 66 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 67 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 68 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 69 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 70 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 71 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 72 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 73 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 74 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 75 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 76 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 77 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 78 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 79 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 80 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 81 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 82 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 83 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 84 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 85 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 86 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 87 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 88 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 89 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 90 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 91 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 92 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 93 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 94 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 95 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 96 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 97 von 100 geht an TwoPlyValuePlayer [singleton] ( black )
# Spiel 98 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
# Spiel 99 von 100 geht an TwoPlyValuePlayer [blocker] ( white )
#
# {'black': 28, 'white': 72}
# 100 Spiele in  937.3178586959839 Sekunden

# %% [markdown]
# 2-ply zeigt den Unterschied zwischen blocker und singleton!
